# %% [markdown]
# # Statistics of NMRlipids databank
#
# This notebook plots:
# 1. Distributions of simulation lengths, number of atoms and trajectory sizes
# 2. Distribution of number of lipid components
# 3. Available single component bilayers and binary lipid mixtures
# 4. Pie diagram of temperatures

# %% [markdown]
# # Initializing databank

# %%
import os
import sys
import numpy as np
import json
import matplotlib.pyplot as plt
import mdtraj
import urllib.request
import yaml
import pandas as pd
import seaborn as sns
import collections


sys.path.insert(1, '../../Databank/Scripts/BuildDatabank/')
from databankLibrary import download_link, lipids_dict, databank

path = '../../Databank/Data/Simulations/'
db_data = databank(path)
systems = db_data.get_systems()
# Out:
# /home/osollila/.conda/envs/py39/lib/python3.9/site-packages/MDAnalysis/coordinates/chemfiles.py:108: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   MIN_CHEMFILES_VERSION = LooseVersion("0.9")

# %% [markdown]
# # Plot distributions of simulation lengths, number of atoms and trajectory sizes

# %%
SimulationLengths = []
NumberOfAtoms = []
SizeOfTrajectories = []
EqTimes = []

# Loop over simulations in the Databank
for system in systems:
    EqTimesPath = system['path'] + 'eq_times.json'
    
    if (os.path.isfile(EqTimesPath)):
        with open(EqTimesPath) as f:
            EqTimeDict = json.load(f)
    
    for i in EqTimeDict:
        if EqTimeDict[i] < 100:
            EqTimes.append(EqTimeDict[i])
    
    SimulationLengths.append(system['TRJLENGTH']*0.001)
    NumberOfAtoms.append(system['NUMBER_OF_ATOMS'])
    SizeOfTrajectories.append(system['TRAJECTORY_SIZE']/(1024*1024*1024))
    
print("Number of entries: ",len(systems))
print("Total size of trajectories: ",str(np.sum(SizeOfTrajectories)) + ' Gb')
print("Total time of trajectories: ",str(np.sum(SimulationLengths)) + ' ns')

plt.figure(figsize=(11,11))
distSIMl = plt.hist(SimulationLengths, density=True,bins=np.arange(0,4500,200))
plt.xlabel('Simulation length (ns)', fontsize=18)
plt.ylabel('Distribution', fontsize=18)
plt.yticks(color='w')
plt.xticks(fontsize=15)
plt.savefig('../../DataBankManuscriptText/Figures/LengthDist.pdf')
plt.figure()
distNatoms = plt.hist(NumberOfAtoms, density=True)
plt.xlabel('Number of atoms in the system')
plt.ylabel('Distribution')
plt.figure()
disttrjSIZE = plt.hist(SizeOfTrajectories, density=True)
plt.xlabel('Size of the trajectory file (Gb)')
plt.ylabel('Distribution')
plt.figure()
distEQtimes = plt.hist(EqTimes, density=True,bins=np.arange(0,10,0.1))
plt.xlabel('Relative equilibration time')
plt.ylabel('Distribution')
# Out:
# Number of entries:  724
# Total size of trajectories:  1732.28134314809 Gb
# Total time of trajectories:  376846.25388413516 ns
# Text(0, 0.5, 'Distribution')

# %%
SimulationLengths = []
NumberOfAtoms = []
SizeOfTrajectories = []
EqTimes = []

# Loop over simulations in the Databank
for system in systems:
    EqTimesPath = system['path'] + 'eq_times.json'
    
    if (not os.path.isfile(EqTimesPath)):
        continue
    
    #print(EqTimesPath)
    #print(system['ID'])
    
    with open(EqTimesPath) as f:
        EqTimeDict = json.load(f)
    
    SimulationLength = system['TRJLENGTH']*0.001
    
    
    for i in EqTimeDict:
        if EqTimeDict[i] < 10:
            SimulationLengths.append(SimulationLength)
            #print(SimulationLength,EqTimeDict[i])
            EqTimes.append(EqTimeDict[i])
    
    NumberOfAtoms.append(system['NUMBER_OF_ATOMS'])
    SizeOfTrajectories.append(system['TRAJECTORY_SIZE']/(1024*1024*1024))
    
print("Number of entries: ",len(systems))
print("Total size of trajectories: ",str(np.sum(SizeOfTrajectories)) + ' Gb')
print("Total time of trajectories: ",str(np.sum(SimulationLengths)) + ' ns')
# Out:
# Number of entries:  724
# Total size of trajectories:  1593.1553354756907 Gb
# Total time of trajectories:  431094.28588413517 ns

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# some random data
#x = np.random.randn(1000)
#y = np.random.randn(1000)

x = np.array(SimulationLengths)
y = np.array(EqTimes)

def scatter_hist(x, y, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)

    # the scatter plot:
    ax.scatter(x, y)

    # now determine nice limits by hand:
    #binwidth = 10.0
    #xymax = max(np.max(np.abs(x)), np.max(np.abs(y)))
    #lim = (int(xymax/binwidth) + 1) * binwidth

    #print(xymax, lim)
    #bins = np.arange(-lim, lim + binwidth, binwidth)
    ax_histx.hist(x, bins=50)
    ax_histy.hist(y, bins=100, orientation='horizontal')
    

    
# Start with a square Figure.
fig = plt.figure(figsize=(6, 6))
# Add a gridspec with two rows and two columns and a ratio of 1 to 4 between
# the size of the marginal axes and the main axes in both directions.
# Also adjust the subplot parameters for a square plot.
gs = fig.add_gridspec(2, 2,  width_ratios=(4, 1), height_ratios=(1, 4),
                      left=0.1, right=0.9, bottom=0.1, top=0.9,
                      wspace=0.05, hspace=0.05)
# Create the Axes.
ax = fig.add_subplot(gs[1, 0])
ax_histx = fig.add_subplot(gs[0, 0], sharex=ax)
ax_histy = fig.add_subplot(gs[1, 1], sharey=ax)
# Draw the scatter plot and marginals.
scatter_hist(x, y, ax, ax_histx, ax_histy)

# %%
y
# Out:
# array([1.57871834e+00, 2.66215734e-01, 1.27759516e+00, 5.13183554e-01,
#        2.33011033e+00, 1.22467840e+00, 3.26048880e-01, 2.61630844e+00,
#        1.79933660e+00, 8.11965745e-02, 1.44849553e+00, 1.71676967e+00,
#        3.32182233e+00, 6.15069165e-01, 8.58640628e-01, 1.03177122e+00,
#        6.20006703e-01, 1.40439023e+00, 1.39192667e-01, 4.90856987e+01,
#        1.29116671e+00, 1.30217374e+02, 4.23902527e-02, 7.54835833e-01,
#        7.59741175e-01, 3.83002701e-02, 2.61374977e+00, 6.59121144e-01,
#        3.09865888e-01, 6.87000080e+00, 5.78943161e+00, 6.53524314e-02,
#        3.31003244e-01, 1.52864171e-01, 1.51590082e-01, 1.15155266e+00,
#        2.22196072e+00, 2.71736456e-01, 1.37836110e-01, 1.17467632e-01,
#        1.34275768e+00, 1.29327067e+00, 3.22983763e-01, 2.25661187e-01,
#        3.18812404e-01, 2.40942770e+00, 1.29046086e+00, 1.26871665e+00,
#        4.44396115e-02, 3.01654257e-01, 3.17105675e-01, 8.71531488e-01,
#        4.22254640e-01, 3.55478651e+00, 1.60081963e+00, 2.78447338e+00,
#        1.89825764e+00, 1.59607664e+00, 2.49862666e+00, 4.45329411e-02,
#        8.37671944e-01, 2.18426741e-01, 3.38854809e-01, 1.12325271e+00,
#        3.79503850e-01, 1.90275760e+00, 2.08139657e+00, 4.46002473e-02,
#        6.47547366e-01, 8.39776209e-02, 1.65259981e+00, 5.55353565e+00,
#        1.33911894e+00, 5.60825232e-01, 6.65003138e+00, 3.10340923e-01,
#        2.70460809e+00, 1.12797696e+00, 1.72231588e+00, 2.46112535e-01,
#        1.52863832e-01, 2.04909357e-01, 1.88314467e-01, 1.24702439e+00,
#        2.87322425e-01, 2.36102552e+00, 1.05960259e-01, 6.94319145e-01,
#        7.56559583e-01, 3.79111002e-02, 3.61417040e-02, 3.37531983e-01,
#        3.34537893e-01, 1.09852923e-01, 7.53694238e-02, 5.19208278e-01,
#        7.36783772e-01, 7.49925795e-01, 2.93530554e-01, 2.90880504e-01,
#        3.52612290e-01, 2.02927970e+00, 7.54927644e-02, 1.08943724e-01,
#        1.05383873e-01, 1.87049062e+00, 1.88743389e+00, 9.39614891e-01,
#        3.76820126e-02, 3.30030754e-01, 2.29776910e-01, 3.18427033e-01,
#        4.82877654e-01, 1.02720388e+02, 8.57711700e-01, 2.43583381e-01,
#        6.21200919e-01, 4.22409941e-01, 3.47875529e-02, 2.61865539e-01,
#        3.15868876e-01, 6.43363307e-01, 6.62283545e-01, 5.72953568e-01,
#        1.16198966e+00, 1.34769903e+00, 3.37748235e-02, 4.38627674e-01,
#        6.29003249e-01, 6.82010924e-01, 3.07616603e+00, 7.02797426e+00,
#        1.56083194e+00, 2.36125731e-01, 2.79694775e-01, 2.60540490e+00,
#        6.68437473e+03, 7.07087302e-01, 6.90048734e-01, 1.29572101e+01,
#        2.50852901e-01, 1.07662135e-01, 2.15458546e-01, 1.30353969e+00,
#        1.25882488e+00, 8.74412862e-01, 6.76391290e+00, 1.71280806e+00,
#        1.98474659e+00, 4.88823684e-01, 5.67175255e-02, 1.67513494e+00,
#        4.36827855e-01, 3.92973009e-01, 3.17542087e+00, 1.57746125e-01,
#        1.06805183e+00, 1.10839346e+00, 2.96041525e+00, 1.09336086e-01,
#        1.87802556e-01, 8.95574015e-02, 1.15115138e-01, 1.12213885e-01,
#        1.05600757e-01, 1.49441346e+00, 1.78817466e-01, 1.94367557e+00,
#        1.72989462e+00, 2.79546388e-01, 2.76597347e-01, 3.54322176e-01,
#        2.99502279e-01, 7.81797307e-01, 7.95511191e-01, 5.26899428e-01,
#        8.75578661e-01, 1.47359590e-01, 7.61529472e-01, 5.23414469e-01,
#        2.04959426e-01, 2.16328304e-01, 1.41535213e-01, 3.36954186e+00,
#        5.23140673e+00, 2.04343165e+00, 2.11597379e+00, 1.45652224e+00,
#        1.55920425e+01, 6.50761983e-01, 3.43679949e-01, 1.90721777e-01,
#        1.19848608e-01, 1.20649762e-01, 4.53449415e+00, 3.88399075e+00,
#        7.76503137e-02, 1.67898941e+00, 3.33513941e-01, 3.77669159e-01,
#        9.88181197e-02, 3.03823556e-01, 7.65261808e+00, 6.49961623e+00,
#        7.20157307e-01, 3.23206069e+00, 3.01983195e-01, 1.82707561e+00,
#        1.50759796e+00, 3.31612938e-01, 2.66887534e-01, 3.54748387e-01,
#        6.11167612e-01, 6.36266151e-02, 1.07808572e+00, 1.13706855e+00,
#        2.48284036e+00, 4.93268813e-01, 5.80502533e-01, 4.06291610e-01,
#        4.13558949e-01, 1.40511586e+00, 1.13929111e+00, 1.17770490e+00,
#        1.28227206e+00, 1.28233962e-01, 2.42354049e-01, 2.85470410e-01,
#        2.84382155e-01, 1.55232439e+00, 7.14835763e-01, 7.86532639e-01,
#        7.49506163e-01, 1.97170604e-01, 2.02833608e-01, 7.83884151e-01,
#        6.84656282e-01, 5.97257099e-02, 2.22018533e+00, 1.82710905e+00,
#        1.63820326e+00, 1.36700712e-01, 3.12574791e-01, 2.08398228e-01,
#        1.64632800e+00, 1.64276207e+00, 1.31473692e+00, 4.40224128e-01,
#        2.56499724e+00, 6.57936666e+00, 3.06700247e-01, 1.24271240e+00,
#        1.33618816e+00, 9.46128265e-01, 1.23218551e+00, 3.44085173e-01,
#        1.27828661e-01, 1.25266438e-01, 8.90951381e+00, 7.52259736e-01,
#        5.75617215e-01, 1.95760450e+00, 7.89699359e-01, 4.51664635e-02,
#        3.65358666e-01, 1.46897303e+00, 4.61693281e+00, 5.55283891e-01,
#        6.64011141e-01, 1.07452992e-01, 1.55921467e-01, 2.17180502e+00,
#        3.15137016e+00, 1.42745572e+00, 1.43911133e+00, 9.16555359e+01,
#        2.51118330e+00, 5.65795436e-01, 3.93716808e-01, 4.13966563e-01,
#        2.33130915e-01, 2.24174364e-01, 5.75453190e-02, 2.84160042e+00,
#        4.46633754e+00, 3.44504685e-01, 3.29912944e-01, 4.47785274e-01,
#        1.44745360e+00, 1.68630098e+00, 3.04675983e-01, 3.05531281e+01,
#        3.06837476e+01, 1.75855668e-01, 5.50969451e-02, 7.24174025e-01,
#        7.31399123e-01, 4.51502004e-02, 3.08974100e+00, 1.04282258e-01,
#        2.38450959e+00, 1.52588860e+00, 2.36342258e+00, 1.69106108e+00,
#        4.32403499e-01, 4.70191005e-01, 2.34750576e+00, 2.66969416e+00,
#        6.46252926e+00, 5.00597690e-02, 3.22681054e-01, 3.12539810e-01,
#        1.43066192e-01, 2.22039794e+00, 8.68304742e-01, 2.70192935e-02,
#        3.23777636e-01, 1.15548225e+00, 1.61698238e-01, 1.33470295e-01,
#        5.14886168e+00, 7.55866221e-01, 8.49390499e-01, 2.26508779e-01,
#        4.01017165e-01, 4.27249894e-01, 1.88895155e-01, 1.97683594e-01,
#        2.89728252e-01, 5.94445905e-01, 1.98891792e-01, 6.88009896e-01,
#        6.18370322e-01, 2.37294504e-01, 5.19740608e+00, 7.68664407e-02,
#        3.45414252e+00, 2.15080525e-01, 2.44501616e-01, 2.43013305e-01,
#        9.29888265e+00, 3.63390283e+00, 5.00254342e-01, 1.68818730e+01,
#        5.15635863e-01, 1.43281616e+00, 3.20013236e+00, 3.34574404e-01,
#        3.92587423e-01, 1.92695857e-01, 2.91145816e-01, 2.43679678e+00,
#        2.31550288e+00, 2.36167117e+00, 1.30608091e-01, 7.49153521e-02,
#        1.06647553e-01, 1.93656332e+00, 1.96009686e+00, 1.02278300e+00,
#        1.75675252e-01, 7.15658778e+03, 6.50827005e+00, 3.09503214e+00,
#        1.32490272e-01, 1.87390600e+00, 8.75342904e+00, 1.10929631e+01,
#        5.34906194e-02, 1.35607491e+00, 1.28571726e+00, 1.82692703e+00,
#        8.46425134e+00, 8.75541992e-02, 1.43033114e+00, 2.12824715e+00,
#        2.70809167e+00, 2.15001383e+00, 5.49228745e+00, 3.71905397e-01,
#        2.84006873e+01, 8.92476524e-02, 6.31038344e-02, 2.26647350e-01,
#        1.65920925e-01, 2.30834117e-01, 1.09995709e-01, 3.48132125e-01,
#        7.27126983e-01, 8.27600807e-01, 7.38482132e-01, 6.41370243e-02,
#        2.04505849e+02, 1.91585378e+00, 5.46103243e+00, 4.12282689e+00,
#        4.29134101e-02, 5.37145904e-02, 2.56178148e+00, 7.95990911e-01,
#        1.61021385e-01, 8.35353710e-02, 6.25588603e-01, 1.49787779e-01,
#        1.58511540e+00, 1.96272353e+00, 1.91009625e+00, 1.89140913e+00,
#        1.04301640e+00, 1.18908328e+00, 2.53511995e+00, 7.69829960e-01,
#        2.52293321e+00, 4.91562578e+00, 2.51294412e-01, 1.92625650e+00,
#        1.05809459e+00, 9.45575591e-01, 1.31133964e+00, 5.91834146e-02,
#        3.30230411e-01, 2.58787643e-01, 2.13966112e+00, 1.55605774e+03,
#        2.97759616e+01, 6.48343972e-01, 5.61015803e-01, 4.22863564e-01,
#        2.23712817e+00, 2.63425819e-01, 6.27086573e-01, 7.80839606e-01,
#        1.98667369e+00, 4.00860696e+02, 6.63961648e+02, 4.74247453e-01,
#        4.59340404e-01, 1.02893216e+00, 3.39118397e+00, 2.77854892e-01,
#        1.93932595e-01, 2.02215187e-01, 1.50097084e+00, 1.75978295e+00,
#        1.23583638e+01, 6.45997840e-01, 1.79539922e+00, 1.75021813e+00,
#        4.68500540e-01, 3.40534042e-02, 4.46285170e+00, 6.36700203e-01,
#        4.72204508e-02, 1.94575187e+00, 8.82897413e-02, 2.05096205e-01,
#        4.99625898e-01, 6.68557740e-01, 6.79141054e-01, 1.18130276e+00,
#        3.06660438e-01, 2.93551309e-01, 2.46447327e-01, 1.47843565e+00,
#        9.92032114e-01, 7.44593149e-01, 3.00796475e-01, 3.12415621e-01,
#        6.27759219e-01, 6.46642278e-01, 7.12063002e-02, 2.98328614e+00,
#        9.33297072e-01, 8.68698947e-01, 1.16347079e+00, 1.16445654e+00,
#        4.23404291e-01, 1.61215040e+00, 2.41187717e-01, 3.01603578e+00,
#        2.65275154e-01, 2.46255263e-01, 6.53671946e-01, 1.01546840e-01,
#        1.36035347e-01, 2.03073001e-01, 3.90940210e-01, 2.24501082e-01,
#        3.40572922e-01, 3.21774904e-01, 1.21957321e+00, 1.07480266e+00,
#        1.92448988e-01, 4.01669800e-01, 2.35302281e-01, 1.82026199e-01,
#        1.29196652e+00, 6.60283589e-01, 1.43827579e-01, 4.41304353e-01,
#        4.85543507e-01, 4.74149716e-01, 5.15469686e-02, 5.59564553e-01,
#        7.21115177e-01, 7.49727062e-01, 6.79227467e+00, 3.02478607e-01,
#        9.48936485e-02, 8.20937862e-01, 2.56701200e+00, 2.97546509e-01,
#        4.78332181e+00, 2.18693951e+00, 1.53335140e+00, 4.34709638e-01,
#        3.82362783e+00, 2.93884998e-01, 1.39037311e+00, 1.35443227e+00,
#        1.15926176e+01, 1.23982241e+00, 6.36647281e-01, 6.75646771e-02,
#        3.17940994e+00, 3.04700062e+00, 5.55789931e-01, 1.32679221e+00,
#        1.03762861e-01, 1.87466073e+00, 1.77006569e+00, 1.54895879e+00,
#        1.19998518e+00, 1.30281481e+00, 7.32653154e-01, 3.24640946e+00,
#        3.08255002e-01, 7.22298031e-01, 2.71292220e-01, 1.91861716e-01,
#        2.00465180e-01, 7.71328567e-02, 1.73323106e+00, 6.57955885e-01,
#        4.27195468e-01, 1.33978155e+00, 3.51416993e-02, 5.06941281e-01,
#        1.47769285e+00, 1.20424255e+00, 1.19748650e+00, 1.32868441e+00,
#        5.90841466e+00, 4.05704237e+00, 3.23791080e+00, 4.53085515e+00,
#        3.02538079e-01, 3.42504681e-01, 1.16013447e+01, 5.82162366e+00,
#        1.28603431e+00, 6.98409316e-01, 2.26304432e+00, 2.31075896e+00,
#        3.91211208e+00, 6.18303401e-01, 2.21095345e+00, 5.91957414e-01,
#        1.59166763e+01, 1.68266141e+00, 3.03395385e-01, 2.88905858e-01,
#        2.36123560e+00, 2.62863893e-01, 2.67445436e+00, 4.11277312e-01,
#        3.90550122e-01, 4.09299536e-01, 1.45062739e+00, 1.04305759e+00,
#        1.04431861e+00, 6.70267194e-01, 3.42136998e-01, 1.29474634e+00,
#        1.50500825e+00, 2.82719426e-01, 3.70219881e-01, 3.62949161e-01,
#        6.40905222e-01, 7.28250962e-01, 1.59348757e-01, 3.85231274e-01,
#        2.14801522e-01, 3.71407018e-01, 9.11034831e-01, 7.06241192e-01,
#        6.33020792e-01, 8.99419925e-01, 3.80553596e+00, 2.52601667e-01,
#        1.33849746e+00, 8.92055179e-02, 1.37912442e+00, 3.12253264e-01,
#        2.96340814e-01, 1.48562880e+00, 9.19470375e-02, 1.01549272e+00,
#        5.96131144e-01, 5.12548613e+00, 1.00019029e+00, 8.99745010e-01,
#        6.00540877e+00, 2.48080689e-01, 2.37285470e-01, 4.96467056e-02,
#        5.22906929e-01, 1.40041254e-01, 6.67100487e-01, 5.19521550e-02,
#        1.79943620e+00, 1.51568022e+00, 1.38571574e+01, 2.38499485e+00,
#        3.30606646e+00, 6.94014413e-02, 1.77653793e+00, 3.81178597e-01,
#        1.39251963e-01, 2.76153091e-01, 2.53156296e+00, 2.75659779e-01,
#        1.53585549e-01, 4.23405828e+00, 2.37207284e+01, 1.29983410e-01,
#        5.24541690e-02, 2.83159925e-01, 2.97194746e-01, 2.88831588e-01,
#        1.03902423e-01, 2.58248498e-01, 3.29999985e+00, 3.16454716e+00,
#        2.05733343e+00, 1.43359615e+00, 5.51619412e-01, 6.83031132e-01,
#        8.46595880e-01, 1.14045100e+00, 2.67848095e+00, 1.65334708e+00,
#        1.73602386e+00, 1.81332460e-01, 2.88833745e+00, 2.68486977e-01,
#        5.00164372e+00, 2.77578224e+00, 1.23367267e+00, 1.22793293e+00,
#        9.74284424e-01, 8.00019891e-01, 5.46946858e-01, 1.67392569e+00,
#        1.05822334e+00, 5.37116912e+08, 2.70227529e-01, 1.26410601e-01,
#        7.55195230e-02, 5.98784688e-01, 2.52919412e-01, 1.07131342e-01,
#        1.34280576e+00, 2.21755162e+00, 2.57928402e+00, 1.36483057e-01,
#        4.29392562e-01, 4.11407535e-01, 2.73397548e+00, 1.33896886e-01,
#        6.48096334e-01, 1.30370551e-01, 1.37044634e+00, 1.16544189e+00,
#        3.21082636e-01, 3.15020088e-01, 1.72042452e+00, 6.30887105e-01,
#        2.06652617e+00, 5.54204774e-02, 3.85064918e-01, 4.24914853e-01,
#        2.91727520e-01, 3.38010574e-01, 3.30372227e-02, 3.06304592e-02,
#        2.60524019e-01, 3.48497643e-01, 3.45009149e-01, 5.43763297e-01,
#        5.60830059e-01, 1.23326197e+00, 1.06084202e-01, 7.88100457e-01,
#        7.48051419e-01, 5.93203481e-02, 2.04677735e-02, 8.55810698e-01,
#        4.97816728e-01, 2.81449829e-02, 2.43351572e-01, 2.52517497e-01,
#        2.36157052e+00, 2.63352704e+00, 7.00246168e-01, 7.22108002e-02,
#        2.38940533e+00, 2.27157608e+00, 1.31738728e-01, 5.52051842e-02,
#        1.78499691e+00, 6.13505885e-01, 1.25315626e+00, 5.62722105e-01,
#        3.91735504e-01, 2.70964302e-01, 2.73208499e-01, 5.29335550e-01,
#        3.68975799e+00, 7.58237104e-01, 5.74775393e-01, 2.62877961e-01,
#        2.97678472e+00, 2.56400203e-01, 2.33666542e-01, 7.15857176e-01,
#        1.26101135e+00, 1.66247597e+00, 1.51234507e+00, 3.10278150e-01,
#        8.15847310e-01, 1.38602484e+00, 1.23728040e+00, 6.05303261e+00,
#        9.21904676e+00, 9.77651812e-02, 2.56941820e+00, 2.25925548e+00,
#        3.71956872e-02, 3.53957630e-02, 2.81136530e-01, 2.64084838e-01,
#        1.23684306e-01, 6.32699537e-01, 4.08557873e-01, 3.74498998e-01,
#        3.07304728e-01, 3.17666157e-01, 3.70163473e-01, 3.72506217e-01,
#        1.99827078e-01, 5.62470723e+00, 2.72209459e-01, 1.41467493e+00,
#        1.46212523e+00, 1.84090721e+00, 1.46667254e+00, 6.74986664e+00,
#        2.76914716e-01, 3.65595492e-01, 2.15611770e-01, 6.85037228e-02,
#        5.19528327e+00, 4.49609889e+00, 1.25730087e+00, 3.25588959e-01,
#        3.40703243e-01, 5.86183292e-02, 3.29636923e-01, 2.55027912e-01,
#        2.83598247e-01, 4.21669352e-02, 5.48239239e-01, 4.10659437e-01,
#        3.96728348e-01, 4.07535065e-01, 2.15578037e-01, 1.63324770e+00,
#        1.75016070e+00, 7.72028615e-02, 7.39532216e+00, 2.12590908e+01,
#        1.81770461e+00, 6.89981416e-01, 3.29074282e-01, 5.32534827e-01,
#        3.12005130e-01, 3.22439044e-01, 1.42068894e+00, 1.24033914e+00,
#        1.75980941e+00, 2.83789894e+00, 7.61446466e-02, 4.88158692e+00,
#        9.75524481e-01, 1.18736051e-01, 1.03857316e+00, 1.06871916e+24,
#        1.66088624e+00, 1.71453662e+00, 9.62111530e-01, 7.03628723e-01,
#        4.62579808e+01, 2.22479414e-01, 1.28683664e-01, 1.56695157e+00,
#        2.79916919e+00, 5.81456903e-01, 2.04081023e+00, 3.78560474e-02,
#        4.21376151e-01, 4.02856202e-01, 5.80904976e-01, 1.38846628e+00,
#        1.29907244e+00, 1.62711780e+00, 8.28433187e-01, 1.41232373e+00,
#        1.71779317e+00, 8.95101813e-02, 6.57331736e-01, 3.31711478e+00,
#        2.44486170e+00, 3.19117523e-01, 2.66711091e-01, 9.82036589e-01,
#        1.24587712e+00, 1.24530066e-01, 1.46918012e+00, 1.04551529e+00,
#        4.48205615e+00, 1.36403375e+00, 1.21220058e+00, 1.92365143e-01,
#        2.09354846e+00, 2.06388147e+00, 1.53886064e-01, 1.61422562e-01,
#        6.70041425e-01, 3.67387586e-01, 6.71408358e+00, 1.41804174e+00,
#        1.96455468e+00, 9.28402567e-02, 2.26733953e+00, 7.39462408e+00,
#        4.71164328e+00, 6.96164093e-01, 4.93676352e-01, 2.87310128e-01,
#        4.24497645e+00])

# %% [markdown]
# # Plot distribution of number of lipid components

# %%
Nlipids = []

# Loop over simulations in the Databank
for system in systems:
    NlipidsTMP = 0
    for molecule in system['COMPOSITION']:
        if molecule in lipids_dict:
            NlipidsTMP += 1
    Nlipids.append(NlipidsTMP)
    
bins=[0.7,1.3, 1.7,2.3, 2.7,3.3, 3.7,4.3, 4.7, 5.3]
distNlipids = plt.hist(Nlipids, density=True, range=[0,6], bins=bins)
plt.xlabel('Number of compositions')
plt.ylabel('Distribution')
plt.figure()

# %% [markdown]
# # Plot available single component bilayers and binary lipid mixtures

# %%
compositions = {}
for lipid in lipids_dict:
    compositions[lipid] = {}

for key in compositions:
    for lipid in lipids_dict:
        compositions[key][lipid] = 0


# Loop over simulations in the Databank
for system in systems:
    lipids_in_system = []
    for mol in system['COMPOSITION']:
        if mol in lipids_dict:
            lipids_in_system.append(mol)
    
    for lipid1 in lipids_in_system:
        for lipid2 in lipids_in_system:
            if lipid1 != lipid2:
                compositions[lipid1][lipid2] += 1
            #print(mol,system['COMPOSITION'][mol]['COUNT'])
            #compositions[mol] =
    
    if len(lipids_in_system) == 1:
        lipid = lipids_in_system[0]
        compositions[lipid][lipid] += 1

df = pd.DataFrame(compositions)
z=df.values

sns.set(rc = {'figure.figsize':(10,7)})
ax = sns.heatmap(df, cmap = 'Greens', vmin =0, vmax = 3, linewidths = 1, linecolor = 'black')
ax.invert_yaxis()
plt.savefig('../../../DataBankManuscriptText/Figures/systems.pdf', bbox_inches='tight')

# %%
df
# Out:
#               POPC  POPG  POPS  POPE  PYPC  PAzePCprot  PAzePCdeprot  DMPC  \
# POPC           208    36    60     4     0           1             1     0
# POPG            36    11     0    15     0           0             0     0
# POPS            60     0    21     0     0           0             0     0
# POPE             4    15     0    23     0           0             0     0
# PYPC             0     0     0     0     3           0             0     0
# PAzePCprot       1     0     0     0     0           0             0     0
# PAzePCdeprot     1     0     0     0     0           0             0     0
# DMPC             0     0     0     0     0           0             0     5
# DPPC             0     0     0     0     0           0             0     0
# DPPE             0     0     0     0     0           0             0     0
# DPPG             0     0     0     0     0           0             0     0
# DEPC             0     0     0     0     0           0             0     0
# DRPC             0     0     0     0     0           0             0     0
# DYPC             0     0     0     0     0           0             0     0
# DLPC             0     0     0     0     0           0             0     0
# DLIPC            0     0     0     0     0           0             0     0
# DOG              0     0     0     4     0           0             0     0
# DOPC             0     0     0     0     0           0             0     0
# DOPE             1     0     0     0     0           0             0     0
# DDOPC            0     0     0     0     0           0             0     0
# DOPS             0     0     0     0     0           0             0     0
# DSPC             0     0     0     0     0           0             0     0
# DAPC             0     0     0     0     0           0             0     0
# DMTAP            0     0     0     0     0           0             0     9
# SOPC             0     0     0     0     0           0             0     0
# POPI             0     0     0     0     0           0             0     1
# SAPI             0     0     0     0     0           0             0     1
# SLPI             0     0     0     0     0           0             0     1
# CER              5     0     0     0     0           0             0     0
# CHOL           123     0     0     0     0           0             0     0
# DCHOL            0     0     0     0     0           0             0     0
# DHMDMAB         13     0     0     0     0           0             0     0
# SLiPC            0     0     0     0     0           0             0     0
#
#               DPPC  DPPE  ...  DMTAP  SOPC  POPI  SAPI  SLPI  CER  CHOL  \
# POPC             0     0  ...      0     0     0     0     0    5   123
# POPG             0     0  ...      0     0     0     0     0    0     0
# POPS             0     0  ...      0     0     0     0     0    0     0
# POPE             0     0  ...      0     0     0     0     0    0     0
# PYPC             0     0  ...      0     0     0     0     0    0     0
# PAzePCprot       0     0  ...      0     0     0     0     0    0     0
# PAzePCdeprot     0     0  ...      0     0     0     0     0    0     0
# DMPC             0     0  ...      9     0     1     1     1    0     0
# DPPC            53     0  ...      0     0     0     0     0    0    16
# DPPE             0     3  ...      0     0     0     0     0    0     0
# DPPG             0     0  ...      0     0     0     0     0    0     0
# DEPC             0     0  ...      0     0     0     0     0    0     0
# DRPC             0     0  ...      0     0     0     0     0    0     0
# DYPC             0     0  ...      0     0     0     0     0    0     0
# DLPC             0     0  ...      0     0     0     0     0    0     0
# DLIPC            0     0  ...      0     0     0     0     0    0     2
# DOG              0     0  ...      0     0     0     0     0    0     0
# DOPC             3     0  ...      0     0     0     0     0    0    22
# DOPE             0     0  ...      0     0     0     0     0    0     0
# DDOPC            0     0  ...      0     0     0     0     0    0     2
# DOPS             0     0  ...      0     0     0     0     0    0     0
# DSPC             0     0  ...      0     0     0     0     0    0     0
# DAPC             0     0  ...      0     0     0     0     0    0    15
# DMTAP            0     0  ...      0     0     0     0     0    0     0
# SOPC             0     0  ...      0     6     0     0     0    0     0
# POPI             0     0  ...      0     0     0     1     1    0     0
# SAPI             0     0  ...      0     0     1     0     1    0     0
# SLPI             0     0  ...      0     0     1     1     0    0     0
# CER              0     0  ...      0     0     0     0     0    0     0
# CHOL            16     0  ...      0     0     0     0     0    0     0
# DCHOL            2     0  ...      0     0     0     0     0    0     0
# DHMDMAB          0     0  ...      0     0     0     0     0    0     0
# SLiPC            0     0  ...      0     0     0     0     0    0     0
#
#               DCHOL  DHMDMAB  SLiPC
# POPC              0       13      0
# POPG              0        0      0
# POPS              0        0      0
# POPE              0        0      0
# PYPC              0        0      0
# PAzePCprot        0        0      0
# PAzePCdeprot      0        0      0
# DMPC              0        0      0
# DPPC              2        0      0
# DPPE              0        0      0
# DPPG              0        0      0
# DEPC              0        0      0
# DRPC              0        0      0
# DYPC              0        0      0
# DLPC              0        0      0
# DLIPC             0        0      0
# DOG               0        0      0
# DOPC              0        0      0
# DOPE              0        0      0
# DDOPC             0        0      0
# DOPS              0        0      0
# DSPC              0        0      0
# DAPC              0        0      0
# DMTAP             0        0      0
# SOPC              0        0      0
# POPI              0        0      0
# SAPI              0        0      0
# SLPI              0        0      0
# CER               0        0      0
# CHOL              0        0      0
# DCHOL             0        0      0
# DHMDMAB           0        0      0
# SLiPC             0        0      3
#
# [33 rows x 33 columns]

# %% [markdown]
# # Plotting pie diagram of temperatures

# %%
#db_data.pie_temperature()
import collections
temps = [ int(float(system['TEMPERATURE'])) for system in systems]
counter = collections.Counter(temps)
plt.pie(counter.values(),labels=counter.keys());

# %%
distTemps = plt.hist(temps, density=True, bins=np.arange(280,365,4))
plt.xlabel('Temperature')
plt.ylabel('Distribution')
plt.figure()

# %%
temps = [ system['FF'] for system in systems]
counter = collections.Counter(temps)
plt.pie(counter.values(),labels=counter.keys());

# %%
ffs = []

for system in systems:
    try:
        ff = system['FF']
    except:
        print('Force field information missing from' + system['path'])
    
    if 'GROMOS-CKP' in ff or 'gromos-ckp' in ff:
        ffs.append('GROMOS-CKP')
    elif 'Charmm-Drude' in ff:
        ffs.append('Charmm-Drude')
    elif 'Berger' in ff:
        ffs.append('Berger')    
    elif 'Slipids' in ff or 'slipids' in ff:
        ffs.append('Slipids')    
    elif 'lipid17ecc' in ff or 'ECC-lipids' in ff:
        ffs.append('ECClipids')
    elif 'ECC-CHARMM36' in ff:
        ffs.append(ff)
    elif 'CHARMM36' in ff:
        ffs.append('CHARMM36')
    elif 'Lipid14' in ff or 'Lipid17' in ff or 'lipid17' in ff:
        ffs.append('Amber Lipid14/17')
    elif 'Poger' in ff:
        ffs.append('Poger')
    else:
        ffs.append(ff)
    
counter = collections.Counter(ffs)
several = {}
several['Others'] = 0
less = {}
for i in counter:
    if counter[i] > 5:
        several[i] = counter[i]
    else:
        several['Others'] += counter[i] 
        less[i] = counter[i]
#plt.pie(counter.values(),labels=counter.keys(), textprops={'fontsize': 15});
plt.pie(several.values(),labels=several.keys(), textprops={'fontsize': 15});
plt.savefig('../../../DataBankManuscriptText/Figures/FFpie.pdf', bbox_inches='tight')
print(less)
# Out:
# {'ECC-CHARMM36': 3, 'Orange': 5, 'Poger': 4, 'GROMOS 43A1-S3': 2, 'GAFFlipid': 3, 'OPLS3e': 1, 'Ulmschneider': 2, 'Chiu Gromos': 1}

# %%
for i in ffs:
    #if 'gromos' in i:
    print(i)
# Out:
# Berger
# CHARMM36
# Slipids
# CHARMM36
# MacRog
# Berger
# Slipids
# Slipids
# CHARMM36
# CHARMM36
# CHARMM36
# MacRog
# Slipids
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# Berger
# Berger
# CHARMM36
# Amber Lipid14/17
# CHARMM36
# Berger
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# CHARMM36
# MacRog
# Charmm-Drude
# Berger
# ECC-CHARMM36
# Berger
# Slipids
# CHARMM36
# CHARMM36
# Berger
# Slipids
# CHARMM36
# Amber Lipid14/17
# MacRog
# Berger
# Berger
# Slipids
# CHARMM36
# ECClipids
# Slipids
# MacRog
# CHARMM36
# Berger
# CHARMM36
# Amber Lipid14/17
# Charmm-Drude polarizable; system has been equilibriated using Charmm36
# CHARMM36
# Amber Lipid14/17
# Slipids
# CHARMM36
# Amber Lipid14/17
# ECClipids
# Slipids
# CHARMM36
# CHARMM36
# Berger
# CHARMM36
# Slipids
# Slipids
# Amber Lipid14/17
# ECClipids
# Orange
# Slipids
# CHARMM36
# Berger
# CHARMM36
# CHARMM36
# ECClipids
# Slipids
# Amber Lipid14/17
# Berger
# Slipids
# ECClipids
# Slipids
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# ECClipids
# CHARMM36
# CHARMM36
# CHARMM36
# ECC-CHARMM36
# MacRog
# CHARMM36
# CHARMM36
# CHARMM36
# ECClipids
# CHARMM36
# CHARMM36
# CHARMM36
# Berger
# CHARMM36
# ECClipids
# Slipids
# Slipids
# ECClipids
# Slipids
# Amber Lipid14/17
# CHARMM36
# Slipids
# ECClipids
# Amber Lipid14/17
# Poger
# CHARMM36
# ECClipids
# GROMOS-CKP
# MacRog
# CHARMM36
# GROMOS-CKP
# ECClipids
# CHARMM36
# MacRog
# CHARMM36
# Berger
# ECClipids
# Slipids
# CHARMM36
# MacRog
# GROMOS-CKP
# Slipids
# CHARMM36
# CHARMM36
# CHARMM36
# Slipids
# CHARMM36
# Berger
# Berger
# CHARMM36
# Amber Lipid14/17
# Slipids
# CHARMM36
# CHARMM36
# CHARMM36
# Berger
# CHARMM36
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# CHARMM36
# Amber Lipid14/17
# ECClipids
# Berger
# CHARMM36
# CHARMM36
# MacRog
# ECClipids
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# GROMOS 43A1-S3
# ECClipids
# CHARMM36
# CHARMM36
# CHARMM36
# Berger
# GAFFlipid
# GROMOS-CKP
# CHARMM36
# CHARMM36
# MacRog
# OPLS3e
# CHARMM36
# Amber Lipid14/17
# MacRog
# Orange
# Berger
# Amber Lipid14/17
# Amber Lipid14/17
# CHARMM36
# Slipids
# CHARMM36
# CHARMM36
# Slipids
# ECClipids
# CHARMM36
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# Amber Lipid14/17
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# Slipids
# CHARMM36
# Berger
# ECClipids
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# ECClipids
# GROMOS-CKP
# Slipids
# Slipids
# Berger
# MacRog
# CHARMM36
# Berger
# Berger
# CHARMM36
# Berger
# CHARMM36
# Slipids
# ECClipids
# Slipids
# CHARMM36
# ECClipids
# Slipids
# Poger
# ECClipids
# Berger
# Slipids
# CHARMM36
# CHARMM36
# CHARMM36
# Slipids
# MacRog
# Slipids
# CHARMM36
# Amber Lipid14/17
# Berger
# CHARMM36
# Berger
# Amber Lipid14/17
# CHARMM36
# Amber Lipid14/17
# MacRog
# Slipids
# Slipids
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# GROMOS-CKP
# Amber Lipid14/17
# ECClipids
# Amber Lipid14/17
# MacRog
# CHARMM36
# Slipids
# Slipids
# Slipids
# CHARMM36
# CHARMM36
# Berger
# CHARMM36
# MacRog
# CHARMM36
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# Berger
# CHARMM36
# MacRog
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# CHARMM36
# Berger
# CHARMM36
# MacRog
# CHARMM36
# Amber Lipid14/17
# Amber Lipid14/17
# ECC-CHARMM36
# Berger
# MacRog
# Slipids
# CHARMM36
# CHARMM36
# ECClipids
# Poger
# Slipids
# Slipids
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# CHARMM36
# CHARMM36
# CHARMM36
# ECClipids
# Slipids
# Berger
# MacRog
# Slipids
# GROMOS-CKP
# CHARMM36
# ECClipids
# CHARMM36
# Slipids
# Berger
# CHARMM36
# Berger
# Amber Lipid14/17
# Slipids
# Orange
# Amber Lipid14/17
# CHARMM36
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# Slipids
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# Slipids
# ECClipids
# CHARMM36
# Slipids
# CHARMM36
# GROMOS-CKP
# CHARMM36
# CHARMM36
# GROMOS-CKP
# Slipids
# CHARMM36
# CHARMM36
# ECClipids
# CHARMM36
# ECClipids
# Amber Lipid14/17
# Slipids
# CHARMM36
# Slipids
# ECClipids
# CHARMM36
# Charmm-Drude polarizable; system has been equilibriated using Charmm36
# CHARMM36
# CHARMM36
# ECClipids
# Slipids
# CHARMM36
# ECClipids
# CHARMM36
# MacRog
# CHARMM36
# Slipids
# GROMOS-CKP
# CHARMM36
# Amber Lipid14/17
# CHARMM36
# Amber Lipid14/17
# ECClipids
# Slipids
# Slipids
# Berger
# Amber Lipid14/17
# Berger
# MacRog
# Slipids
# Berger
# GROMOS 43A1-S3
# Slipids
# Slipids
# Berger
# CHARMM36
# Slipids
# CHARMM36
# Charmm-Drude polarizable; system has been equilibriated using Charmm36
# Slipids
# CHARMM36
# Slipids
# Slipids
# CHARMM36
# CHARMM36
# Berger
# Slipids
# Ulmschneider
# ECClipids
# CHARMM36
# ECClipids
# Slipids
# ECClipids
# Slipids
# Slipids
# CHARMM36
# MacRog
# ECClipids
# Amber Lipid14/17
# Amber Lipid14/17
# GROMOS-CKP
# CHARMM36
# MacRog
# Berger
# Berger
# CHARMM36
# Slipids
# CHARMM36
# Amber Lipid14/17
# CHARMM36
# CHARMM36
# GROMOS-CKP
# CHARMM36
# CHARMM36
# Slipids
# Slipids
# CHARMM36
# Slipids
# Slipids
# CHARMM36
# ECClipids
# Slipids
# Amber Lipid14/17
# CHARMM36
# Slipids
# CHARMM36
# Charmm-Drude polarizable; system has been equilibriated using Charmm36
# CHARMM36
# GAFFlipid
# Berger
# MacRog
# Charmm-Drude polarizable; system has been equilibriated using Charmm36
# CHARMM36
# Slipids
# CHARMM36
# Slipids
# CHARMM36
# CHARMM36
# GROMOS-CKP
# ECClipids
# GAFFlipid
# CHARMM36
# Berger
# CHARMM36
# Slipids
# Slipids
# Orange
# Slipids
# CHARMM36
# CHARMM36
# Berger
# CHARMM36
# Slipids
# Slipids
# Slipids
# GROMOS-CKP
# CHARMM36
# Slipids
# GROMOS-CKP
# Slipids
# MacRog
# Slipids
# Poger
# Slipids
# CHARMM36
# Slipids
# Chiu Gromos
# GROMOS-CKP
# Berger
# Amber Lipid14/17
# MacRog
# Berger
# ECClipids
# Berger
# Berger
# ECClipids
# Berger
# CHARMM36
# MacRog
# Amber Lipid14/17
# Berger
# Amber Lipid14/17
# CHARMM36
# ECClipids
# CHARMM36
# CHARMM36
# CHARMM36
# Berger
# Amber Lipid14/17
# CHARMM36
# Slipids
# Slipids
# Slipids
# Amber Lipid14/17
# Berger
# ECClipids
# Slipids
# GROMOS-CKP
# CHARMM36
# ECClipids
# CHARMM36
# Amber Lipid14/17
# ECClipids
# Ulmschneider
# CHARMM36
# CHARMM36
# ECClipids
# Berger
# ECClipids
# Orange
# CHARMM36
# CHARMM36
# CHARMM36
# MacRog
# CHARMM36
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# MacRog
# CHARMM36
# Charmm-Drude polarizable; system has been equilibriated using Charmm36
# CHARMM36
# ECClipids
# GROMOS-CKP
# CHARMM36
# CHARMM36
# GROMOS-CKP
# Amber Lipid14/17
# CHARMM36
# GROMOS-CKP
# GROMOS-CKP
# CHARMM36
# CHARMM36
# ECClipids
# Slipids
# Amber Lipid14/17
# Charmm-Drude polarizable; system has been equilibriated using Charmm36
# GROMOS-CKP
# Amber Lipid14/17
# Slipids
# Amber Lipid14/17
# Slipids
# CHARMM36
# Slipids
# CHARMM36
# CHARMM36
# GROMOS-CKP
# CHARMM36
# Charmm-Drude polarizable; system has been equilibriated using Charmm36
# GROMOS-CKP
# CHARMM36
# CHARMM36
# CHARMM36
# Slipids
# CHARMM36
# Slipids
# CHARMM36
# Berger
# CHARMM36
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# Berger
# MacRog
# Slipids
# Amber Lipid14/17
# MacRog
# CHARMM36
# MacRog
# CHARMM36
# MacRog
# ECClipids
# Slipids
# CHARMM36
# Berger
# CHARMM36
# Amber Lipid14/17
# Slipids
# ECClipids
# CHARMM36
# CHARMM36
# Berger
# Slipids
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# Slipids
# MacRog
# CHARMM36
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# ECClipids
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# Slipids
# Slipids
# Amber Lipid14/17
# ECClipids
# CHARMM36
# Slipids
# ECClipids
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# CHARMM36
# Slipids
# GROMOS-CKP
# CHARMM36
# Slipids
# GROMOS-CKP
# GROMOS-CKP
# CHARMM36
# Charmm-Drude
# Slipids
# CHARMM36
# ECClipids
# CHARMM36
# MacRog
# Amber Lipid14/17
# ECClipids
# Amber Lipid14/17
# CHARMM36
# Berger
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# CHARMM36
# Slipids
# Amber Lipid14/17
# Amber Lipid14/17
# CHARMM36
# MacRog
# Amber Lipid14/17
# Slipids
# ECClipids
# Slipids
# ECClipids
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# Amber Lipid14/17
# CHARMM36
# Berger
# Amber Lipid14/17
# CHARMM36
# Slipids
# CHARMM36
# Berger
# Slipids
# CHARMM36
# ECClipids
# ECClipids
# ECClipids
# Berger
# CHARMM36
# GROMOS-CKP
# CHARMM36
# CHARMM36
# Berger
# Berger
# Amber Lipid14/17
# Slipids
# Berger
# CHARMM36
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# CHARMM36
# ECClipids
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# Slipids
# GROMOS-CKP
# ECClipids
# ECClipids
# Amber Lipid14/17
# CHARMM36
# CHARMM36
# Charmm-Drude polarizable; system has been equilibriated using Charmm36
# ECClipids
# Amber Lipid14/17
# CHARMM36
# GROMOS-CKP
# GROMOS-CKP
# Amber Lipid14/17
# CHARMM36
# Slipids
# CHARMM36
# Slipids
# CHARMM36
# ECClipids
# Amber Lipid14/17
# MacRog
# Amber Lipid14/17
# CHARMM36
# CHARMM36
# CHARMM36
# Amber Lipid14/17
# Amber Lipid14/17
# Slipids
# CHARMM36
# CHARMM36

# %%
lipids = []
for system in systems:
    for lipid in system['COMPOSITION']:
        if lipid in lipids_dict:
            lipids.append(lipid)
counter = collections.Counter(lipids)
several = {}
several['Others'] = 0
less = {}
for i in counter:
    if counter[i] > 9:
        several[i] = counter[i]
    else:
        several['Others'] += counter[i] 
        less[i] = counter[i]

#plt.figure(figsize=(11,5))
plt.pie(several.values(),labels=several.keys(), textprops={'fontsize': 14});
plt.savefig('../../../DataBankManuscriptText/Figures/FFlipids.pdf', bbox_inches='tight')
print(less)
# Out:
# {'PYPC': 3, 'SOPC': 6, 'DOG': 4, 'DLPC': 8, 'DYPC': 3, 'DMTAP': 9, 'DLIPC': 5, 'DCHOL': 2, 'CER': 5, 'DEPC': 1, 'DRPC': 3, 'DOPE': 8, 'SAPI': 1, 'POPI': 1, 'SLPI': 1, 'PAzePCprot': 1, 'DSPC': 2, 'DPPG': 2, 'DPPE': 3, 'PAzePCdeprot': 1, 'SLiPC': 3, 'DDOPC': 2}

# %%
print(len(several))
print(len(less))
print(len(several) + len(less))
# Out:
# 12
# 22
# 34

# %%
def getTotalNlipids(system):
    NLIPIDS = 0
    for molecule in system['COMPOSITION']:
        if molecule in lipids_dict:
            NLIPIDS += np.sum(system['COMPOSITION'][molecule]['COUNT'])
    return NLIPIDS

def getTotalNsolvent(system):
    NMOLECULES = 0
    for molecule in system['COMPOSITION']:
        if molecule not in lipids_dict:
            NMOLECULES += np.sum(system['COMPOSITION'][molecule]['COUNT'])
    return NMOLECULES

def checkAvailabilitySIM(system,lipid,counterion):
    status = {}
    TotalNlipids = getTotalNlipids(system)
    TotalNsolvent = getTotalNsolvent(system)
    Nwater = system['COMPOSITION']['SOL']['COUNT']
    if counterion != 'no':
        try:
            Ncounterion = system['COMPOSITION'][counterion]['COUNT']
        except:
            Ncounterion = 0
    
    try:
        Nlipid = np.sum(system['COMPOSITION'][lipid]['COUNT'])
    except:
        Nlipid = 0
    
    path = system['path']
    
    QualityEvaluated = False
    TotalQualityFilePath = path + '/SYSTEM_quality.json'
    if (os.path.isfile(TotalQualityFilePath)):
        with open(TotalQualityFilePath) as json_file:
            Quality = json.load(json_file)
        json_file.close()
        if all(value > 0 for value in Quality.values()):
            #print(Quality)
            QualityEvaluated = True
            
    xrayQualityEvaluated = False
    xrayQualityFilePath = path + '/FormFactorQuality.json'
    if (os.path.isfile(xrayQualityFilePath)):
        with open(xrayQualityFilePath) as json_file:
            xrayQuality = json.load(json_file)
        json_file.close()
        if len(xrayQuality) > 0 and xrayQuality[0] > 0:
            xrayQualityEvaluated = True
    
    SingleComponentSystem = False
    if Nlipid == TotalNlipids:
        if counterion == 'no' and Nwater == TotalNsolvent:
            SingleComponentSystem = True
        if counterion != 'no'and  Nwater == TotalNsolvent-Ncounterion and Nlipid == Ncounterion:    
            SingleComponentSystem = True
        
    if SingleComponentSystem:
        status['Simulation'] = 'yes'
        status['FF'] = system['FF']
        if QualityEvaluated:
            status['Experiment'] = 'yes'
            status['Quality'] = Quality['total']
            
        if not QualityEvaluated:
            status['Experiment'] = 'no'
            status['Quality'] = 0 
            
        if xrayQualityEvaluated:
            status['xrayExperiment'] = 'yes'
            status['xrayQuality'] = xrayQuality[0]
            
        if not xrayQualityEvaluated:
            status['xrayExperiment'] = 'no'
            status['xrayQuality'] = 0 
                
    return status 
        
        
def giveStatus(systems,lipid,counterion):  
    status = {'Simulation': 'no', 'Experiment': 'no', 'Quality': 0, 'xrayExperiment': 'no', 'xrayQuality': 0}
    QualityEvaluatedFound = False
    for system in systems:
        TMPstatus = checkAvailabilitySIM(system,lipid,counterion)
        if TMPstatus and TMPstatus['Quality'] > status['Quality']:
            QualityEvaluatedFound = True
            status = TMPstatus 
        if TMPstatus and not QualityEvaluatedFound and TMPstatus['Simulation'] == 'yes':
            status = TMPstatus
    return status
    
def giveExpStatus(lipids,counterion,status):

    

    return status


    
HGs = {'PC', 'PE', 'PG', 'PS'}
tails = {'PO', 'DO', 'DP'}
table = {}

for tail in tails:
    table[tail] = {}
    for HG in HGs:
        lipid = tail + HG
        
        if lipid == 'POPS' or lipid == 'POPG' or lipid == 'DPPG':
            counterion = 'SOD'
        else:
            counterion = 'no'
        
        status = giveStatus(systems,lipid,counterion)
        statusString = ''
            
        if status['Quality'] > 0:
            if 'ECC-lipids' in status['FF']:
                FF = 'ECClipids'
            else:
                FF = status['FF']
            #print(status['xrayQuality'])
            statusString = FF + '(' + str(round(status['Quality'],2)) + ',' + str(round(status['xrayQuality'])) + ')'
        else:
            if status['Simulation'] == 'no':
                statusString = statusString + 'MD,'
            if status['Experiment'] == 'no':
                statusString = statusString + 'NMR,'
            if status['xrayExperiment'] == 'no':
                statusString = statusString + 'x-ray'
            
        table[tail][HG] = statusString
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [10], in <module>
#     112 else:
#     113     counterion = 'no'
# --> 115 status = giveStatus(systems,lipid,counterion)
#     116 statusString = ''
#     118 if status['Quality'] > 0:
#
# Input In [10], in giveStatus(systems, lipid, counterion)
#      83 QualityEvaluatedFound = False
#      84 for system in systems:
# ---> 85     TMPstatus = checkAvailabilitySIM(system,lipid,counterion)
#      86     if TMPstatus and TMPstatus['Quality'] > status['Quality']:
#      87         QualityEvaluatedFound = True
#
# Input In [10], in checkAvailabilitySIM(system, lipid, counterion)
#      17 TotalNlipids = getTotalNlipids(system)
#      18 TotalNsolvent = getTotalNsolvent(system)
# ---> 19 Nwater = system['COMPOSITION']['SOL']['COUNT']
#      20 if counterion != 'no':
#      21     try:
#
# KeyError: 'SOL'

# %%
print(pd.DataFrame(table))
display(pd.DataFrame(table))
# Out:
#               DO                  PO            DP
# PE  MD,NMR,x-ray   Slipids(0.52,122)     NMR,x-ray
# PC     NMR,x-ray   Slipids(0.76,515)          NMR,
# PS  MD,NMR,x-ray  ECClipids(0.5,297)  MD,NMR,x-ray
# PG  MD,NMR,x-ray     Slipids(0.23,0)     NMR,x-ray
#               DO                  PO            DP
# PE  MD,NMR,x-ray   Slipids(0.52,122)     NMR,x-ray
# PC     NMR,x-ray   Slipids(0.76,515)          NMR,
# PS  MD,NMR,x-ray  ECClipids(0.5,297)  MD,NMR,x-ray
# PG  MD,NMR,x-ray     Slipids(0.23,0)     NMR,x-ray

# %%
print(pd.DataFrame(table))
display(pd.DataFrame(table))
# Out:
#     DO              PO  DP
# PE   0   Slipids(0.52)   0
# PC   0   Slipids(0.76)   0
# PS   0  ECClipids(0.5)   0
# PG   0   Slipids(0.23)   0
#     DO              PO  DP
# PE   0   Slipids(0.52)   0
# PC   0   Slipids(0.76)   0
# PS   0  ECClipids(0.5)   0
# PG   0   Slipids(0.23)   0

# %%
status['xrayQuality']
# Out:
# 0
